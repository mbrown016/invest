# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

cf = pd.read_csv('MUR.csv')

cf
# Out:
#                                            Unnamed: 0  2011-12  2012-12  \
# 0                Cash Flows From Operating Activities      NaN      NaN
# 1                                          Net income    873.0    971.0
# 2                         Depreciation & amortization   1093.0   1376.0
# 3   Amortization of debt discount/premium and issu...    179.0    192.0
# 4                 Investment/asset impairment charges    369.0    261.0
# 5                               Deferred income taxes    172.0    317.0
# 6            (Gain) Loss from discontinued operations   -132.0     -7.0
# 7                                 Accounts receivable    -44.0   -309.0
# 8                                           Inventory    -59.0   -158.0
# 9                                    Prepaid expenses     21.0   -243.0
# 10                               Income taxes payable      NaN     41.0
# 11                              Other working capital   -743.0    268.0
# ...

# %%
div = cf.iloc[25] * -1
div
# Out:
# Unnamed: 0
# 2011-12       213
# 2012-12       714
# 2013-12       235
# 2014-12       236
# 2015-12       245
# TTM           243
# Name: 25, dtype: object

# %%
cf.fillna(value = 0, inplace = True)
cf
# Out:
#                                            Unnamed: 0  2011-12  2012-12  \
# 0                Cash Flows From Operating Activities      0.0      0.0
# 1                                          Net income    873.0    971.0
# 2                         Depreciation & amortization   1093.0   1376.0
# 3   Amortization of debt discount/premium and issu...    179.0    192.0
# 4                 Investment/asset impairment charges    369.0    261.0
# 5                               Deferred income taxes    172.0    317.0
# 6            (Gain) Loss from discontinued operations   -132.0     -7.0
# 7                                 Accounts receivable    -44.0   -309.0
# 8                                           Inventory    -59.0   -158.0
# 9                                    Prepaid expenses     21.0   -243.0
# 10                               Income taxes payable      0.0     41.0
# 11                              Other working capital   -743.0    268.0
# ...

# %%
div
# Out:
# Unnamed: 0
# 2011-12       213
# 2012-12       714
# 2013-12       235
# 2014-12       236
# 2015-12       245
# TTM           243
# Name: 25, dtype: object

# %%
debt = cf.iloc[23] + cf.iloc[22]
debt = debt * -1
debt
# Out:
# Unnamed: 0
# 2011-12        340
# 2012-12      -1645
# 2013-12       -350
# 2014-12        -75
# 2015-12       -140
# TTM           -805
# dtype: object

# %%
equity = cf.iloc[24] * -1
sh = div + equity + debt
sh
# Out:
# Unnamed: 0
# 2011-12       553
# 2012-12      -681
# 2013-12       385
# 2014-12       536
# 2015-12       355
# TTM          -562
# dtype: object
